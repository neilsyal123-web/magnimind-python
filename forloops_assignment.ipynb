# %%
current_users=["NEIL","John","sarah","mike","LIsa"]
new_users=["alex","john","emma","lisa","ryan"]
lowered_current=[]
for item in current_users:
    lowered_current.append(item.lower())
for new_name in new_users:
    if(new_name.lower() in lowered_current):
        print("User must enter a different username.")
    else:
        print("Username is available.")
    

def color_probability(color,texture):
    total=0
    numerator=0
    if(texture=="bumpy"):
        total=7
        if(color=="red"):
            numerator=4
        elif(color=="yellow"):
            numerator=2
        else:
            numerator=1
    else:
        total=3
        numerator=1
    probability=str(numerator/total)
    return probability[:4]         

color_probability("red","bumpy")


age=int(input("Enter an age: "))
if(age<2):
    print("Person is a baby.")
elif(age<4):
    print("Person is a toddler.")
elif(age<13):
    print("Person is a kid.")
elif(age<20):
    print("Person is a teenager.")
elif(age<65):
    print("Person is an adult.")
else:
    print("Person is an elder.")
# Out:
# Username is available.
# User must enter a different username.
# Username is available.
# User must enter a different username.
# Username is available.
# '0.57'
