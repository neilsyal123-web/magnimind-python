# %%
dictionary={1:"Monday", 2:"Tuesday", 3:"Wednesday", 4:"Thursday", 5:"Friday" , 6:"Saturday" , 7:"Sunday"}
days_gone=input("Enter 2 different days to remove: ")
day1=int(days_gone[0])
day2=int(days_gone[1])
dictionary.pop(day1)
dictionary.pop(day2)
print(dictionary)

dictionary2={"Michael":{"age":20},"Linda":{"age":30}}
dictionary2["Michael"]["children"]={"Karen":{"age":12,"gender":"female"},"Greg":{"age":7,"gender":"male"}}
dictionary2["Linda"]["children"]={"Susan":{"age":6,"gender":"female"}}
print(list(dictionary2["Michael"]["children"].keys()))
# Out:
# Enter 2 different days to remove:  12
# {3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday', 7: 'Sunday'}
# ['Karen', 'Greg']
