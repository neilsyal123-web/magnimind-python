# %%
def problem1():
    try:
        value=5/0
    except ZeroDivisionError:
        print("Can't divide by 0.") 

problem1()

def problem2():
    try:
        print(x)
    except NameError:
        print("Variable was never defined.")

problem2()


def problem3():
    try:
        x=int(input("Enter a number: "))
    except ValueError:
        print(" Enter a number, not a string.")

problem3()

def circumference(diameter):
    try:
        result=2*3.14*diameter
        print(result)
    except TypeError:
        print("Enter a number, not a string: ")

circumference(10)
circumference("hello")
# Out:
# Can't divide by 0.
# Variable was never defined.
