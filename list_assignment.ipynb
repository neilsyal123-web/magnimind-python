# %%
my_list=[34,56,76,45,2,12,67,98,37,54,66]
my_list.sort()
total=my_list[0]+my_list[1]+my_list[-1]+my_list[-2]
print(total)

names=["David", "Michael", "John", "James", "Greg", "Mark", "William", "Richard", "Thomas", "Steven", "Mary", "Susan", "Maria", "Karen", "Lisa", "Linda", "Donna", "Patricia", "Debra", "Eric"]
scores = [99, 87, 78, 86, 68, 94, 76, 97, 56, 98, 76, 87, 79, 90, 73, 93, 82, 69, 97, 98]
name=input("Enter a name: ")
idx= names.index(name)
score=scores[idx]
print(f" {name}'s scored {score}.")

scores.sort(reverse=True)
the_max=scores[0]
the_count= scores.count(the_max)
print(f" The highest score was {the_max} and {the_count} students earned that score.")
# Out:
# 188
# Enter a name:  David
#  David's scored 99.
#  The highest score was 99 and 1 students earned that score.
